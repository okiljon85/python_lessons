# %% [markdown]
# <a href="https://colab.research.google.com/github/okiljon85/python_lessons/blob/main/first_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Salom")
# Out:
# Salom

# %% [markdown]
# # Heading
#  - [Kirish](https://mohirdev.uz)
#  - Muqaddima

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import tensorflow as tf
import keras

# %%
tf.__version__
# Out:
# '2.6.0'

# %%
torch.__version__
# Out:
# '1.9.0+cu102'

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
! ls
# Out:
# sample_data

# %%
import pandas as pd
files = pd.read_excel("./data/TS_6_ta.xlsx")

files.head()
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2  ... Unnamed: 68 Unnamed: 69 Unnamed: 70
# 0   № Тов-ра    КодТНВЭД     Страна  ...         NaN         NaN          Да
# 1          1  8501109300        156  ...         NaN         NaN         NaN
# 2          2  8501109300        156  ...         NaN         NaN         NaN
# 3          3  7411290000        156  ...         NaN         NaN         NaN
# 4          4  7411101000        156  ...         NaN         NaN         NaN
#
# [5 rows x 71 columns]
